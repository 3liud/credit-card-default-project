# %% [markdown]
# ## Exploring the financial history features in the Dataset
# the financial history feature fall into three groups:
# - the stauts of the ontly pauemts for the last 6 months
# - the billed amount
# - paid amounts
# for the same period

# %%
# importing libraries
import pandas as pd
import numpy as np

# plotting package
import matplotlib.pyplot as plt

# rednder plotting automatically
# %matplotlib inline

# additinal plotting functionality
import matplotlib as mpl

# high resolution figures
mpl.rcParams['figure.dpi'] = 400

# %%
# load data
df = pd.read_csv('../Data/Chp_1_cleaned_data.csv')

# %% [markdown]
# ### Payment statuses
# - broken down as a list to study them together

# %%
# specifyign the feature columns needed
pay_feats = ['PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']

# %%
df[pay_feats].describe()
# Out:
#               PAY_1         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  26664.000000  26664.000000  26664.000000  26664.000000  26664.000000
# mean      -0.017777     -0.133363     -0.167679     -0.225023     -0.269764
# std        1.126769      1.198640      1.199165      1.167897      1.131735
# min       -2.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       -1.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        8.000000      8.000000      8.000000      8.000000      8.000000
#
#               PAY_6
# count  26664.000000
# mean      -0.293579
# std        1.150229
# min       -2.000000
# 25%       -1.000000
# 50%        0.000000
# 75%        0.000000
# max        8.000000

# %% [markdown]
# - 9 i.e. payment delay for nine months and above is not observed
# - values range the same for all features here: -2, -1, 0, ... 8

# %%
# checking PAY_1 value counts sorted by index of this seris
df[pay_feats[0]].value_counts().sort_index()
# Out:
# -2     2476
# -1     5047
#  0    13087
#  1     3261
#  2     2378
#  3      292
#  4       63
#  5       23
#  6       11
#  7        9
#  8       17
# Name: PAY_1, dtype: int64

# %% [markdown]
# most of the values are either
# - -2 - not used,
# - -1 - paid in full, or
# - 0 - made at least the minimum payment
#
# ---
#
# - 1 = payment delay for 1 month
# - 2 =  payment delay for 2 months
# and so on

# %%
# visualizing recent month's payment status feature
df[pay_feats[0]].hist()
# Out:
# <AxesSubplot:>
